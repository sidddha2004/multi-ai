# %%
import setup
setup.init()
# Out:
# Working directory: d:\multi-ai\multi_ai_agent
# Django initialized successfully

# %%
from ai_agents.agents import get_task_agent

agent = get_task_agent()

agent.invoke({
    "messages":[("user","create a task called finish AI assignment for user id 1")]
})
# Out:
# {'messages': [HumanMessage(content='create a task called finish AI assignment for user id 1', additional_kwargs={}, response_metadata={}, id='9cc72f31-bc87-4aaa-ae22-5f8420f9c70a'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'create_task', 'arguments': '{"user_id": 1, "title": "finish AI assignment"}'}, '__gemini_function_call_thought_signatures__': {'b5fd3bb5-def2-442d-9b3b-83973dad33f0': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, name='task agent', id='lc_run--019cd3ed-232e-7540-86c8-43c99eaf70c7-0', tool_calls=[{'name': 'create_task', 'args': {'user_id': 1, 'title': 'finish AI assignment'}, 'id': 'b5fd3bb5-def2-442d-9b3b-83973dad33f0', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 251, 'output_tokens': 95, 'total_tokens': 346, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 71}}),
# ...
