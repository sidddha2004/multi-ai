# %%
import setup

setup.init()
# Out:
# Working directory: d:\multi-ai\multi_ai_agent
# Django initialized successfully

# %%
from ai_agents.tools import create_task

create_task.invoke(
    {
        "user_id":1,
        "title":"finish homework"
    }
)
# Out:
# 'Task finish homework created successfully'
