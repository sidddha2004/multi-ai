# %%
import setup

setup.init()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import setup
#       3 setup.init()
#
# File d:\multi-ai\multi_ai_agent\notebook\setup.py:5
#       2 import sys
#       3 import pathlib
# ----> 5 from dotenv import load_dotenv
#       7 NOTEBOOKS_DIR = pathlib.Path(__file__).parent
#       8 REPO_ROOT = NOTEBOOKS_DIR.parent
#
# ModuleNotFoundError: No module named 'dotenv'

# %%
from ai_agents.graph import build_graph

app = build_graph()

app.invoke({
    "message": "create a task called finish assignment for user id 1"
})
