# %%
import setup
setup.init()
# Out:
# Working directory: d:\multi-ai\multi_ai_agent
# Django initialized successfully

# %%
from ai_agents.supervisor import get_supervisor

router = get_supervisor()

agent = router("create task finish project")

agent.invoke({
    "messages":[("user","create task finish project for user id 1")]
})
# Out:
# {'messages': [HumanMessage(content='create task finish project for user id 1', additional_kwargs={}, response_metadata={}, id='90466d95-876b-4cca-9ae4-a6ddd942fd1c'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'create_task', 'arguments': '{"user_id": 1, "title": "finish project"}'}, '__gemini_function_call_thought_signatures__': {'7457b2df-d3ef-4291-8b23-afbc99d71be5': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, name='task agent', id='lc_run--019cd405-f881-78e2-a805-a17215ddaeb7-0', tool_calls=[{'name': 'create_task', 'args': {'user_id': 1, 'title': 'finish project'}, 'id': '7457b2df-d3ef-4291-8b23-afbc99d71be5', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 248, 'output_tokens': 107, 'total_tokens': 355, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 84}}),
# ...
